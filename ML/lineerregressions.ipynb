# %% [markdown]
# # Basit Doğrusal Regresyon

# %%
from warnings import filterwarnings
filterwarnings('ignore')

# %%
import pandas as pd
ad = pd.read_csv("Advertising.csv")

# %%
df = ad.copy()
df.head()
# Out:
#    Unnamed: 0     TV  radio  newspaper  sales
# 0           1  230.1   37.8       69.2   22.1
# 1           2   44.5   39.3       45.1   10.4
# 2           3   17.2   45.9       69.3    9.3
# 3           4  151.5   41.3       58.5   18.5
# 4           5  180.8   10.8       58.4   12.9

# %%
df = df.iloc[:,1:len(df)]

# %%
df.head()
# Out:
#       TV  radio  newspaper  sales
# 0  230.1   37.8       69.2   22.1
# 1   44.5   39.3       45.1   10.4
# 2   17.2   45.9       69.3    9.3
# 3  151.5   41.3       58.5   18.5
# 4  180.8   10.8       58.4   12.9

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 200 entries, 0 to 199
# Data columns (total 4 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   TV         200 non-null    float64
#  1   radio      200 non-null    float64
#  2   newspaper  200 non-null    float64
#  3   sales      200 non-null    float64
# dtypes: float64(4)
# memory usage: 6.4 KB

# %%
df.describe().T
# Out:
#            count      mean        std  min     25%     50%      75%    max
# TV         200.0  147.0425  85.854236  0.7  74.375  149.75  218.825  296.4
# radio      200.0   23.2640  14.846809  0.0   9.975   22.90   36.525   49.6
# newspaper  200.0   30.5540  21.778621  0.3  12.750   25.75   45.100  114.0
# sales      200.0   14.0225   5.217457  1.6  10.375   12.90   17.400   27.0

# %%
df.isnull().values.any()
# Out:
# False

# %%
df.corr()
# Out:
#                  TV     radio  newspaper     sales
# TV         1.000000  0.054809   0.056648  0.782224
# radio      0.054809  1.000000   0.354104  0.576223
# newspaper  0.056648  0.354104   1.000000  0.228299
# sales      0.782224  0.576223   0.228299  1.000000

# %%
import seaborn as sns
sns.pairplot(data=df,kind="reg")

# %%
sns.jointplot(x="TV",y="sales",data=df,kind="reg");

# %% [markdown]
# statmodels

# %%
import statsmodels.api as sm

# %%
x = df[["TV"]]
x
# Out:
#         TV
# 0    230.1
# 1     44.5
# 2     17.2
# 3    151.5
# 4    180.8
# ..     ...
# 195   38.2
# 196   94.2
# 197  177.0
# 198  283.6
# 199  232.1
#
# [200 rows x 1 columns]

# %%
x = sm.add_constant(x)

# %%
x[0:5]
# Out:
#    const     TV
# 0    1.0  230.1
# 1    1.0   44.5
# 2    1.0   17.2
# 3    1.0  151.5
# 4    1.0  180.8

# %%
y = df[["sales"]]

y
# Out:
#      sales
# 0     22.1
# 1     10.4
# 2      9.3
# 3     18.5
# 4     12.9
# ..     ...
# 195    7.6
# 196    9.7
# 197   12.8
# 198   25.5
# 199   13.4
#
# [200 rows x 1 columns]

# %%
lm = sm.OLS(y,x)

# %%
model = lm.fit()

# %%
model.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                  sales   R-squared:                       0.612
# Model:                            OLS   Adj. R-squared:                  0.610
# Method:                 Least Squares   F-statistic:                     312.1
# Date:                Tue, 09 Jul 2024   Prob (F-statistic):           1.47e-42
# Time:                        15:26:50   Log-Likelihood:                -519.05
# No. Observations:                 200   AIC:                             1042.
# Df Residuals:                     198   BIC:                             1049.
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const          7.0326      0.458     15.360      0.000       6.130       7.935
# TV             0.0475      0.003     17.668      0.000       0.042       0.053
# ==============================================================================
# Omnibus:                        0.531   Durbin-Watson:                   1.935
# Prob(Omnibus):                  0.767   Jarque-Bera (JB):                0.669
# Skew:                          -0.089   Prob(JB):                        0.716
# Kurtosis:                       2.779   Cond. No.                         338.
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# """

# %%
import statsmodels.formula.api as smf
lm = smf.ols("sales ~ TV",df)
model = lm.fit()
model.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                  sales   R-squared:                       0.612
# Model:                            OLS   Adj. R-squared:                  0.610
# Method:                 Least Squares   F-statistic:                     312.1
# Date:                Tue, 09 Jul 2024   Prob (F-statistic):           1.47e-42
# Time:                        15:26:51   Log-Likelihood:                -519.05
# No. Observations:                 200   AIC:                             1042.
# Df Residuals:                     198   BIC:                             1049.
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept      7.0326      0.458     15.360      0.000       6.130       7.935
# TV             0.0475      0.003     17.668      0.000       0.042       0.053
# ==============================================================================
# Omnibus:                        0.531   Durbin-Watson:                   1.935
# Prob(Omnibus):                  0.767   Jarque-Bera (JB):                0.669
# Skew:                          -0.089   Prob(JB):                        0.716
# Kurtosis:                       2.779   Cond. No.                         338.
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# """

# %%
model.params
# Out:
# Intercept    7.032594
# TV           0.047537
# dtype: float64

# %%
model.summary().tables[0]
# Out:
# <class 'statsmodels.iolib.table.SimpleTable'>

# %%
model.summary().tables[1]
# Out:
# <class 'statsmodels.iolib.table.SimpleTable'>

# %%
model.summary().tables[2]
# Out:
# <class 'statsmodels.iolib.table.SimpleTable'>

# %%
model.conf_int()
# Out:
#                   0         1
# Intercept  6.129719  7.935468
# TV         0.042231  0.052843

# %%
model.f_pvalue
# Out:
# 1.4673897001945906e-42

# %%
print("f_pvalue: ", "%.5f" % model.f_pvalue)
# Out:
# f_pvalue:  0.00000

# %%
print("f_value: ", "%.5f" % model.fvalue)
# Out:
# f_value:  312.14499

# %%
model.mse_model
# Out:
# 3314.618166868649

# %%
model.rsquared_adj
# Out:
# 0.6099148238341623

# %%
model.fittedvalues[0:5]
# Out:
# 0    17.970775
# 1     9.147974
# 2     7.850224
# 3    14.234395
# 4    15.627218
# dtype: float64

# %%
y[0:5]
# Out:
#    sales
# 0   22.1
# 1   10.4
# 2    9.3
# 3   18.5
# 4   12.9

# %%
print("Sales : "+ str("%.2f" % model.params[0]) + " + TV" + "*" + str("%.2f"%model.params[1]))
# Out:
# Sales : 7.03 + TV*0.05
# C:\Users\kero\AppData\Local\Temp\ipykernel_4456\49633494.py:1: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   print("Sales : "+ str("%.2f" % model.params[0]) + " + TV" + "*" + str("%.2f"%model.params[1]))

# %%
import pyplot as plt
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[37], line 1
# ----> 1 import pyplot as plt
#
# ModuleNotFoundError: No module named 'pyplot'

# %%
g = sns.regplot(x=df["TV"], y=df["sales"], ci=None, scatter_kws={'color':'r', 's':9})
g.set_title("Model Denklemi: Sales = 7.03 + TV*0.05")
g.set_ylabel("Satış Sayısı")
g.set_xlabel("TV Harcamaları")
import matplotlib.pyplot as plt
plt.xlim(-10,310)
plt.ylim(bottom=0);

# %%
from sklearn.linear_model import LinearRegression
x = df[["TV"]]
y = df[["sales"]]
reg = LinearRegression()
model = reg.fit(x,y)
model.intercept_
model.coef_
# Out:
# array([[0.04753664]])

# %%
model.score(x,y)
# Out:
# 0.611875050850071

# %%
model.predict(x)
# Out:
# array([[17.97077451],
#        [ 9.14797405],
#        [ 7.85022376],
#        [14.23439457],
#        [15.62721814],
#        [ 7.44616232],
#        [ 9.76595037],
#        [12.74649773],
#        [ 7.44140866],
#        [16.53041431],
#        [10.17476548],
#        [17.23871025],
#        [ 8.16396559],
#        [11.66741599],
#        [16.73482186],
#        [16.32125309],
#        [10.25557777],
#        [20.40940417],
#        [10.32212907],
#        [14.03474068],
#        [17.41459582],
#        [18.31779199],
#        [ 7.6600772 ],
#        [17.88520856],
#        [ 9.99412625],
#        [19.52997632],
#        [13.82557947],
#        [18.44614092],
#        [18.85970969],
#        [10.38868036],
#        [20.95607553],
#        [12.39948025],
#        [11.653155  ],
#        [19.65832525],
#        [11.58185004],
#        [20.85149492],
#        [19.72012288],
#        [10.58358059],
#        [ 9.08142275],
#        [17.87094757],
#        [16.65876324],
#        [15.44657891],
#        [20.98935118],
#        [16.86792445],
#        [ 8.22576322],
#        [15.35625929],
#        [11.2966302 ],
#        [18.43663359],
#        [17.83291826],
#        [10.21279479],
#        [16.53041431],
#        [11.80527225],
#        [17.31952254],
#        [15.71278409],
#        [19.52046899],
#        [16.48763133],
#        [ 7.37961102],
#        [13.50708398],
#        [17.05331735],
#        [17.04856369],
#        [ 9.57580381],
#        [19.45391769],
#        [18.4081116 ],
#        [11.91460652],
#        [13.26464711],
#        [10.31262174],
#        [ 8.52999772],
#        [13.65444756],
#        [18.31779199],
#        [17.3385372 ],
#        [16.49713866],
#        [12.25211667],
#        [ 8.30657551],
#        [13.18383482],
#        [17.17691262],
#        [ 7.83596277],
#        [ 8.33985116],
#        [12.76075872],
#        [ 7.28929141],
#        [12.54684384],
#        [10.66439288],
#        [18.43187992],
#        [10.61210257],
#        [10.28409975],
#        [17.18166628],
#        [16.21667248],
#        [10.65963921],
#        [12.29489965],
#        [11.2300789 ],
#        [12.25211667],
#        [13.41676436],
#        [ 8.39214147],
#        [17.38132017],
#        [18.95953663],
#        [12.13802873],
#        [14.79532693],
#        [16.4258337 ],
#        [15.82211837],
#        [20.80395828],
#        [13.45954734],
#        [17.60474238],
#        [21.12245377],
#        [20.3523602 ],
#        [15.96472829],
#        [18.3558213 ],
#        [13.58789626],
#        [ 8.22100956],
#        [11.32990584],
#        [ 7.65532354],
#        [19.17345152],
#        [17.76636696],
#        [18.52219954],
#        [15.38478127],
#        [16.99627338],
#        [10.74995883],
#        [10.60259525],
#        [13.6496939 ],
#        [10.66439288],
#        [13.00794925],
#        [ 7.95480437],
#        [13.74952084],
#        [ 7.92628239],
#        [17.68080101],
#        [12.88435399],
#        [17.94225253],
#        [11.17778859],
#        [ 7.40337934],
#        [10.84503211],
#        [17.50491544],
#        [ 9.86577732],
#        [ 7.0658692 ],
#        [19.63931059],
#        [ 7.43190133],
#        [17.48114712],
#        [ 8.78669558],
#        [ 9.32861328],
#        [ 8.24953154],
#        [20.04337204],
#        [ 9.07666909],
#        [15.82211837],
#        [10.52178296],
#        [16.2404408 ],
#        [17.51442276],
#        [12.00492614],
#        [11.60561836],
#        [13.7019842 ],
#        [18.44614092],
#        [18.5935045 ],
#        [ 8.83898589],
#        [ 9.15748138],
#        [20.37612852],
#        [12.78452704],
#        [16.4258337 ],
#        [15.17562006],
#        [15.95997462],
#        [ 7.22749377],
#        [11.49628409],
#        [14.15358229],
#        [ 7.58877224],
#        [13.29316909],
#        [15.23266402],
#        [11.10648363],
#        [15.98849661],
#        [14.80483426],
#        [12.60388781],
#        [18.17993573],
#        [ 7.88349941],
#        [16.86317079],
#        [17.2719859 ],
#        [20.54726042],
#        [ 9.40942557],
#        [14.8523709 ],
#        [ 7.9643117 ],
#        [15.0377638 ],
#        [17.60474238],
#        [20.19548929],
#        [18.84069503],
#        [15.12332975],
#        [20.18598196],
#        [14.9046612 ],
#        [14.47683144],
#        [17.41934948],
#        [ 9.70415274],
#        [20.70413134],
#        [19.09739289],
#        [16.77760484],
#        [13.66395489],
#        [16.11684554],
#        [20.62807271],
#        [ 7.92152873],
#        [ 8.91029085],
#        [10.6216099 ],
#        [ 7.85022376],
#        [14.96170517],
#        [14.14882862],
#        [ 8.84849321],
#        [11.51054508],
#        [15.44657891],
#        [20.51398478],
#        [18.06584779]])
